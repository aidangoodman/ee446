# %% [markdown]
# # EE446 - TinyML - Assignment 2

# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import tensorflow as tf
import seaborn as sns
from pylab import rcParams
from sklearn.model_selection import train_test_split
from tensorflow.keras import datasets, layers,models
from tensorflow.keras.models import Model, load_model, Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Input, Dense, Activation
from tensorflow.keras.callbacks import ModelCheckpoint, TensorBoard
from tensorflow.keras import regularizers
from sklearn.preprocessing import LabelEncoder
import warnings
warnings.filterwarnings("ignore")
from sklearn.utils import class_weight
from sklearn.metrics import accuracy_score
import c_writer
from os.path import join

# %% [markdown]
# ## Reading Data

# %%
# Reading the data and adding column header (feature) names
data = pd.read_csv("Network_anomaly_data.txt",sep=",",names=["duration","protocoltype","service",
"flag","srcbytes","dstbytes","land", "wrongfragment","urgent","hot","numfailedlogins","loggedin", "numcompromised",
"rootshell","suattempted","numroot","numfilecreations", "numshells","numaccessfiles","numoutboundcmds","ishostlogin",
"isguestlogin","count","srvcount","serrorrate", "srvserrorrate","rerrorrate","srvrerrorrate","samesrvrate",
"diffsrvrate", "srvdiffhostrate","dsthostcount","dsthostsrvcount","dsthostsamesrvrate", "dsthostdiffsrvrate",
"dsthostsamesrcportrate","dsthostsrvdiffhostrate","dsthostserrorrate","dsthostsrvserrorrate","dsthostrerrorrate",
"dsthostsrvrerrorrate","attack", "lastflag"])

# %%
data # printing the dataframe
# Out:
#         duration protocoltype   service flag  srcbytes  dstbytes  land  \
# 0              0          tcp  ftp_data   SF       491         0     0
# 1              0          udp     other   SF       146         0     0
# 2              0          tcp   private   S0         0         0     0
# 3              0          tcp      http   SF       232      8153     0
# 4              0          tcp      http   SF       199       420     0
# ...          ...          ...       ...  ...       ...       ...   ...
# 125968         0          tcp   private   S0         0         0     0
# 125969         8          udp   private   SF       105       145     0
# 125970         0          tcp      smtp   SF      2231       384     0
# 125971         0          tcp    klogin   S0         0         0     0
# 125972         0          tcp  ftp_data   SF       151         0     0
#
#         wrongfragment  urgent  hot  ...  dsthostsamesrvrate  \
# 0                   0       0    0  ...                0.17
# 1                   0       0    0  ...                0.00
# 2                   0       0    0  ...                0.10
# 3                   0       0    0  ...                1.00
# 4                   0       0    0  ...                1.00
# ...               ...     ...  ...  ...                 ...
# 125968              0       0    0  ...                0.10
# 125969              0       0    0  ...                0.96
# 125970              0       0    0  ...                0.12
# 125971              0       0    0  ...                0.03
# 125972              0       0    0  ...                0.30
#
#         dsthostdiffsrvrate  dsthostsamesrcportrate  dsthostsrvdiffhostrate  \
# 0                     0.03                    0.17                    0.00
# 1                     0.60                    0.88                    0.00
# 2                     0.05                    0.00                    0.00
# 3                     0.00                    0.03                    0.04
# 4                     0.00                    0.00                    0.00
# ...                    ...                     ...                     ...
# 125968                0.06                    0.00                    0.00
# 125969                0.01                    0.01                    0.00
# 125970                0.06                    0.00                    0.00
# 125971                0.05                    0.00                    0.00
# 125972                0.03                    0.30                    0.00
#
#         dsthostserrorrate  dsthostsrvserrorrate  dsthostrerrorrate  \
# 0                    0.00                  0.00               0.05
# 1                    0.00                  0.00               0.00
# 2                    1.00                  1.00               0.00
# 3                    0.03                  0.01               0.00
# 4                    0.00                  0.00               0.00
# ...                   ...                   ...                ...
# 125968               1.00                  1.00               0.00
# 125969               0.00                  0.00               0.00
# 125970               0.72                  0.00               0.01
# 125971               1.00                  1.00               0.00
# 125972               0.00                  0.00               0.00
#
#         dsthostsrvrerrorrate   attack  lastflag
# 0                       0.00   normal        20
# 1                       0.00   normal        15
# 2                       0.00  neptune        19
# 3                       0.01   normal        21
# 4                       0.00   normal        21
# ...                      ...      ...       ...
# 125968                  0.00  neptune        20
# 125969                  0.00   normal        21
# 125970                  0.00   normal        18
# 125971                  0.00  neptune        20
# 125972                  0.00   normal        21
#
# [125973 rows x 43 columns]

# %% [markdown]
# ## Question 1: Data Preprocessing

# %% [markdown]
# ##### (a) Drop the 'land', 'urgent', 'numfailedlogins', 'numoutboundcmds' columns from the dataframe "data".

# %%
data = data.drop(['land', 'urgent', 'numfailedlogins', 'numoutboundcmds'], axis=1)

# %% [markdown]
# ##### (b) Change any label that is not named normal to attack in the {'attack'} column of the dataframe data.

# %%
data['attack'] = data['attack'].apply(lambda x: 'normal' if x == 'normal' else 'attack')

# %%
data #<--------- Print your modified dataframe "data"
# Out:
#         duration protocoltype   service flag  srcbytes  dstbytes  \
# 0              0          tcp  ftp_data   SF       491         0
# 1              0          udp     other   SF       146         0
# 2              0          tcp   private   S0         0         0
# 3              0          tcp      http   SF       232      8153
# 4              0          tcp      http   SF       199       420
# ...          ...          ...       ...  ...       ...       ...
# 125968         0          tcp   private   S0         0         0
# 125969         8          udp   private   SF       105       145
# 125970         0          tcp      smtp   SF      2231       384
# 125971         0          tcp    klogin   S0         0         0
# 125972         0          tcp  ftp_data   SF       151         0
#
#         wrongfragment  hot  loggedin  numcompromised  ...  dsthostsamesrvrate  \
# 0                   0    0         0               0  ...                0.17
# 1                   0    0         0               0  ...                0.00
# 2                   0    0         0               0  ...                0.10
# 3                   0    0         1               0  ...                1.00
# 4                   0    0         1               0  ...                1.00
# ...               ...  ...       ...             ...  ...                 ...
# 125968              0    0         0               0  ...                0.10
# 125969              0    0         0               0  ...                0.96
# 125970              0    0         1               0  ...                0.12
# 125971              0    0         0               0  ...                0.03
# 125972              0    0         1               0  ...                0.30
#
#         dsthostdiffsrvrate  dsthostsamesrcportrate  dsthostsrvdiffhostrate  \
# 0                     0.03                    0.17                    0.00
# 1                     0.60                    0.88                    0.00
# 2                     0.05                    0.00                    0.00
# 3                     0.00                    0.03                    0.04
# 4                     0.00                    0.00                    0.00
# ...                    ...                     ...                     ...
# 125968                0.06                    0.00                    0.00
# 125969                0.01                    0.01                    0.00
# 125970                0.06                    0.00                    0.00
# 125971                0.05                    0.00                    0.00
# 125972                0.03                    0.30                    0.00
#
#         dsthostserrorrate  dsthostsrvserrorrate  dsthostrerrorrate  \
# 0                    0.00                  0.00               0.05
# 1                    0.00                  0.00               0.00
# 2                    1.00                  1.00               0.00
# 3                    0.03                  0.01               0.00
# 4                    0.00                  0.00               0.00
# ...                   ...                   ...                ...
# 125968               1.00                  1.00               0.00
# 125969               0.00                  0.00               0.00
# 125970               0.72                  0.00               0.01
# 125971               1.00                  1.00               0.00
# 125972               0.00                  0.00               0.00
#
#         dsthostsrvrerrorrate  attack  lastflag
# 0                       0.00  normal        20
# 1                       0.00  normal        15
# 2                       0.00  attack        19
# 3                       0.01  normal        21
# 4                       0.00  normal        21
# ...                      ...     ...       ...
# 125968                  0.00  attack        20
# 125969                  0.00  normal        21
# 125970                  0.00  normal        18
# 125971                  0.00  attack        20
# 125972                  0.00  normal        21
#
# [125973 rows x 39 columns]

# %% [markdown]
# ##### (c) Use LabelEncoder() function from the sklearn.preprocessing library to convert non-numerical attributes in the {'protocoltype', 'service', 'flag', 'attack'} columns of the dataframe data to numerical values.

# %%
le = LabelEncoder()
cols_to_encode = ['protocoltype', 'service', 'flag', 'attack']
for col in cols_to_encode:
    data[col] = le.fit_transform(data[col])

# %%
pd.DataFrame(data) #<--------- Print your modified dataframe "data"
# Out:
#         duration  protocoltype  service  flag  srcbytes  dstbytes  \
# 0              0             1       20     9       491         0
# 1              0             2       44     9       146         0
# 2              0             1       49     5         0         0
# 3              0             1       24     9       232      8153
# 4              0             1       24     9       199       420
# ...          ...           ...      ...   ...       ...       ...
# 125968         0             1       49     5         0         0
# 125969         8             2       49     9       105       145
# 125970         0             1       54     9      2231       384
# 125971         0             1       30     5         0         0
# 125972         0             1       20     9       151         0
#
#         wrongfragment  hot  loggedin  numcompromised  ...  dsthostsamesrvrate  \
# 0                   0    0         0               0  ...                0.17
# 1                   0    0         0               0  ...                0.00
# 2                   0    0         0               0  ...                0.10
# 3                   0    0         1               0  ...                1.00
# 4                   0    0         1               0  ...                1.00
# ...               ...  ...       ...             ...  ...                 ...
# 125968              0    0         0               0  ...                0.10
# 125969              0    0         0               0  ...                0.96
# 125970              0    0         1               0  ...                0.12
# 125971              0    0         0               0  ...                0.03
# 125972              0    0         1               0  ...                0.30
#
#         dsthostdiffsrvrate  dsthostsamesrcportrate  dsthostsrvdiffhostrate  \
# 0                     0.03                    0.17                    0.00
# 1                     0.60                    0.88                    0.00
# 2                     0.05                    0.00                    0.00
# 3                     0.00                    0.03                    0.04
# 4                     0.00                    0.00                    0.00
# ...                    ...                     ...                     ...
# 125968                0.06                    0.00                    0.00
# 125969                0.01                    0.01                    0.00
# 125970                0.06                    0.00                    0.00
# 125971                0.05                    0.00                    0.00
# 125972                0.03                    0.30                    0.00
#
#         dsthostserrorrate  dsthostsrvserrorrate  dsthostrerrorrate  \
# 0                    0.00                  0.00               0.05
# 1                    0.00                  0.00               0.00
# 2                    1.00                  1.00               0.00
# 3                    0.03                  0.01               0.00
# 4                    0.00                  0.00               0.00
# ...                   ...                   ...                ...
# 125968               1.00                  1.00               0.00
# 125969               0.00                  0.00               0.00
# 125970               0.72                  0.00               0.01
# 125971               1.00                  1.00               0.00
# 125972               0.00                  0.00               0.00
#
#         dsthostsrvrerrorrate  attack  lastflag
# 0                       0.00       1        20
# 1                       0.00       1        15
# 2                       0.00       0        19
# 3                       0.01       1        21
# 4                       0.00       1        21
# ...                      ...     ...       ...
# 125968                  0.00       0        20
# 125969                  0.00       1        21
# 125970                  0.00       1        18
# 125971                  0.00       0        20
# 125972                  0.00       1        21
#
# [125973 rows x 39 columns]

# %% [markdown]
# ## Feature Scaling and Train/Test Split

# %%
# All the features apart from Attack are what we are going to use to predict the attack status of the data
# attack = 1 (normal/not an attack) and attack = 0 (attack)
X = data.drop(['attack'],axis=1).to_numpy()

# Initialize the StandardScaler
scaler = StandardScaler()

# Fit and transform the data
X_normalized = scaler.fit_transform(X)

Y = data['attack'].to_numpy()
# Splitting X and y testing and training data
# we are taking 20% of the data for testing and 80% of the data for training
X_train, X_test, y_train, y_test = train_test_split(X_normalized, Y, test_size = 0.20)
# reshaping y test and train array
y_train = y_train.reshape(len(y_train),1)
y_test = y_test.reshape(len(y_test),1)

# %% [markdown]
# ## Question 2: Dimensionality Reduction for Visualization

# %% [markdown]
# ##### (a) Use TSNE from the sklearn.manifold library to visualize the data in the test set (X_test) in 2D. In your figure, use color "red" to mark {attack} data points and color "blue" to mark {normal} data points.

# %%
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

tsne = TSNE(n_components=2, random_state=42)
X_tsne = tsne.fit_transform(X_test)

# Pass your test labels directly as the color sequence
plt.scatter(X_tsne[:, 0], X_tsne[:, 1], c=y_test, s=5, alpha=0.6, cmap='tab10')
plt.colorbar()  # Optional: adds a legend bar for class labels
plt.show()

# %% [markdown]
# ##### (b) Use PCA from the sklearn.decomposition library to visualize the data in the test set (X_test) in 2D. In your figure, use color "red" to mark {attack} data points and color "blue" to mark {normal} data points.

# %%
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# 1. Fit and transform the data
pca = PCA(n_components=2, random_state=42)
X_pca = pca.fit_transform(X_test)

# 2. Map labels to red (attack) and blue (normal)
# y_test holds the encoded integers, so compare against the encoded
# value of 'attack' rather than the string itself
attack_label = le.transform(['attack'])[0]

colors = ['red' if label == attack_label else 'blue' for label in y_test.ravel()]

# 3. Plot the PCA results
plt.figure(figsize=(8, 6))
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=colors, s=10, alpha=0.6)
plt.title("2D PCA Visualization")
plt.xlabel("Principal Component 1")
plt.ylabel("Principal Component 2")
plt.grid(True)
plt.show()

# %% [markdown]
# ##### (c) Use KernelPCA from the sklearn.decomposition library to visualize the data in the test set (X_test) in 2D. Use radial basis function (rbf) as the kernel. In your figure, use color "red" to mark {attack} data points and color "blue" to mark {normal} data points.

# %%
import matplotlib.pyplot as plt
from sklearn.decomposition import KernelPCA

# 1. Fit and transform the data
kpca = KernelPCA(n_components=2, kernel='rbf', random_state=42)
X_kpca = kpca.fit_transform(X_test)

# 2. Map labels to red (attack) and blue (normal)
# y_test holds the encoded integers, so compare against the encoded
# value of 'attack' rather than the string itself
attack_label = le.transform(['attack'])[0]
colors = ['red' if label == attack_label else 'blue' for label in y_test.ravel()]

# 3. Plot the KernelPCA results
plt.figure(figsize=(8, 6))
plt.scatter(X_kpca[:, 0], X_kpca[:, 1], c=colors, s=10, alpha=0.6)
plt.title("2D KernelPCA (RBF) Visualization")
plt.xlabel("Component 1")
plt.ylabel("Component 2")
plt.grid(True)
plt.show()

# %% [markdown]
# ## Question 3: Implementing a DNN on the dataset

# %% [markdown]
# ##### (a) Implement a deep neural network (DNN) on the Network Anomaly Dataset. Ensure that the output layer contains one neuron with sigmoid activation.

# %%
base_model = Sequential([
    Dense(64, activation='relu', input_shape=(X_train.shape[1],)),
    Dense(32, activation='relu'),
    Dense(16, activation='relu'),
    Dense(1, activation='sigmoid')
])

# %% [markdown]
# ##### (b) Compile and train your DNN model on the training set (X_train). Denote the trained model as base_model.

# %%
base_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
base_model.summary()
history = base_model.fit(X_train, y_train, epochs=20, batch_size=256, validation_split=0.1, verbose=1)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 64)                2496
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dense_2 (Dense)             (None, 16)                528
#
#  dense_3 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 5121 (20.00 KB)
# Trainable params: 5121 (20.00 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/20
# 355/355 [==============================] - 1s 1ms/step - loss: 0.0662 - accuracy: 0.9832 - val_loss: 0.0211 - val_accuracy: 0.9936
# Epoch 2/20
# 355/355 [==============================] - 0s 972us/step - loss: 0.0128 - accuracy: 0.9956 - val_loss: 0.0185 - val_accuracy: 0.9953
# Epoch 3/20
# 355/355 [==============================] - 0s 942us/step - loss: 0.0090 - accuracy: 0.9965 - val_loss: 0.0103 - val_accuracy: 0.9966
# Epoch 4/20
# 355/355 [==============================] - 0s 919us/step - loss: 0.0076 - accuracy: 0.9971 - val_loss: 0.0081 - val_accuracy: 0.9973
# Epoch 5/20
# 355/355 [==============================] - 0s 966us/step - loss: 0.0063 - accuracy: 0.9974 - val_loss: 0.0092 - val_accuracy: 0.9965
# Epoch 6/20
# 355/355 [==============================] - 0s 1ms/step - loss: 0.0052 - accuracy: 0.9980 - val_loss: 0.0083 - val_accuracy: 0.9968
# Epoch 7/20
# 355/355 [==============================] - 0s 941us/step - loss: 0.0049 - accuracy: 0.9981 - val_loss: 0.0070 - val_accuracy: 0.9979
# Epoch 8/20
# 355/355 [==============================] - 0s 925us/step - loss: 0.0042 - accuracy: 0.9985 - val_loss: 0.0074 - val_accuracy: 0.9973
# Epoch 9/20
# 355/355 [==============================] - 0s 946us/step - loss: 0.0040 - accuracy: 0.9986 - val_loss: 0.0084 - val_accuracy: 0.9979
# Epoch 10/20
# 355/355 [==============================] - 0s 937us/step - loss: 0.0036 - accuracy: 0.9986 - val_loss: 0.0073 - val_accuracy: 0.9980
# Epoch 11/20
# 355/355 [==============================] - 0s 942us/step - loss: 0.0036 - accuracy: 0.9989 - val_loss: 0.0075 - val_accuracy: 0.9980
# Epoch 12/20
# 355/355 [==============================] - 0s 970us/step - loss: 0.0031 - accuracy: 0.9989 - val_loss: 0.0088 - val_accuracy: 0.9973
# Epoch 13/20
# 355/355 [==============================] - 0s 925us/step - loss: 0.0034 - accuracy: 0.9990 - val_loss: 0.0070 - val_accuracy: 0.9979
# Epoch 14/20
# 355/355 [==============================] - 0s 964us/step - loss: 0.0030 - accuracy: 0.9989 - val_loss: 0.0071 - val_accuracy: 0.9981
# Epoch 15/20
# 355/355 [==============================] - 0s 1ms/step - loss: 0.0028 - accuracy: 0.9992 - val_loss: 0.0073 - val_accuracy: 0.9980
# Epoch 16/20
# 355/355 [==============================] - 0s 1ms/step - loss: 0.0031 - accuracy: 0.9988 - val_loss: 0.0061 - val_accuracy: 0.9984
# Epoch 17/20
# 355/355 [==============================] - 0s 1ms/step - loss: 0.0026 - accuracy: 0.9991 - val_loss: 0.0056 - val_accuracy: 0.9983
# Epoch 18/20
# 355/355 [==============================] - 0s 1ms/step - loss: 0.0027 - accuracy: 0.9991 - val_loss: 0.0064 - val_accuracy: 0.9982
# Epoch 19/20
# 355/355 [==============================] - 0s 1ms/step - loss: 0.0025 - accuracy: 0.9992 - val_loss: 0.0069 - val_accuracy: 0.9981
# Epoch 20/20
# 355/355 [==============================] - 0s 1ms/step - loss: 0.0024 - accuracy: 0.9991 - val_loss: 0.0051 - val_accuracy: 0.9983

# %% [markdown]
# ##### (c) Evaluate the base_model on the test set (X_test) using classification_report and confusion_matrix from the sklearn.metrics library. Report these numbers in your .pdf writeup file using screenshots.

# %%
y_pred_prob = base_model.predict(X_test)
y_pred = (y_pred_prob > 0.5).astype(int)
print(classification_report(y_test, y_pred))
print(confusion_matrix(y_test, y_pred))
# Out:
# 788/788 [==============================] - 1s 589us/step
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     11809
#            1       1.00      1.00      1.00     13386
#
#     accuracy                           1.00     25195
#    macro avg       1.00      1.00      1.00     25195
# weighted avg       1.00      1.00      1.00     25195
#
# [[11788    21]
#  [   20 13366]]

# %%
# Save the original Keras model to HDF5 file
base_model.save('original_model.h5')

# %% [markdown]
# ## Question 4: Implementing Quantized Model

# %% [markdown]
# ##### (a) Implement full-integer INT8 post-training quantization on the base_model. Use a representative dataset from X_train to calibrate the activation ranges. Configure the converter to use INT8 operators with INT8 input and output tensors. Designate the resulting quantized model as tflite_quant_model.

# %%
# Load the trained model
base_model = tf.keras.models.load_model('original_model.h5')
def representative_dataset():
    for i in range(min(len(X_train), 500)):
        sample = X_train[i:i+1].astype(np.float32)
        yield [sample]

converter = tf.lite.TFLiteConverter.from_keras_model(base_model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
converter.representative_dataset = representative_dataset
converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS_INT8]
converter.inference_input_type = tf.int8
converter.inference_output_type = tf.int8

tflite_quant_model = converter.convert()
# Out:
# INFO:tensorflow:Assets written to: C:\Users\aidan\AppData\Local\Temp\tmp34wgrksx\assets
# INFO:tensorflow:Assets written to: C:\Users\aidan\AppData\Local\Temp\tmp34wgrksx\assets

# %%
import os

# Save the quantized model
with open('quantized_model.tflite', 'wb') as f:
    f.write(tflite_quant_model)

# Get the file sizes
original_model_size = os.path.getsize('original_model.h5')
quantized_model_size = os.path.getsize('quantized_model.tflite')

# Print the model sizes
print(f"Original model size: {original_model_size / 1024:.2f} KB")
print(f"Quantized model size: {quantized_model_size / 1024:.2f} KB")
# Out:
# Original model size: 100.01 KB
# Quantized model size: 8.24 KB

# %% [markdown]
# ##### (b) Evaluate the tflite_quant_model on the test set (X_test) using classification_report and confusion_matrix from the sklearn.metrics library. Report these numbers in your .pdf writeup file using screenshots.

# %%
# Load the quantized model into a TFLite interpreter
interpreter = tf.lite.Interpreter(model_content=tflite_quant_model)
interpreter.allocate_tensors()

input_details = interpreter.get_input_details()[0]
output_details = interpreter.get_output_details()[0]

# Scale/zero point used to quantize inputs and dequantize outputs
input_scale, input_zero_point = input_details['quantization']
output_scale, output_zero_point = output_details['quantization']

y_pred = []
for i in range(len(X_test)):
    sample = X_test[i:i+1].astype(np.float32)

    # Quantize the input sample using the input tensor's scale and zero point
    sample_quant = sample / input_scale + input_zero_point
    sample_quant = np.round(sample_quant).astype(input_details['dtype'])

    interpreter.set_tensor(input_details['index'], sample_quant)
    interpreter.invoke()

    output_quant = interpreter.get_tensor(output_details['index'])

    # Dequantize the output back to a probability using the output tensor's
    # scale and zero point
    output = (output_quant.astype(np.float32) - output_zero_point) * output_scale
    y_pred.append(1 if output[0][0] > 0.5 else 0)

y_pred = np.array(y_pred).reshape(-1, 1)

print("Classification Report:")
print(classification_report(y_test, y_pred))

print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     11809
#            1       1.00      1.00      1.00     13386
#
#     accuracy                           1.00     25195
#    macro avg       1.00      1.00      1.00     25195
# weighted avg       1.00      1.00      1.00     25195
#
# Confusion Matrix:
# [[11784    25]
#  [   38 13348]]

# %% [markdown]
# ## Converting tflite_quant_model to C and creating the header file

# %%
# c_writer is a py file in the same folder and has been imported at the beginning of the notebook
# Reference : https://github.com/ShawnHymel/tinyml-example-anomaly-detection/blob/master/utils/c_writer.py
# We use #04x to pad the output to 2 digits with a 0x prefix
hex_array = [format(val, '#04x') for val in tflite_quant_model]
# Calling function to convert an array into a C string (requires Numpy)
# create_array(np_array, var_type, var_name, line_limit=80, indent=4)
c_model = c_writer.create_array(np.array(hex_array), 'unsigned char', "network_model")
# Calling Function to create a header file with given C code as a string
header_str = c_writer.create_header(c_model, "network_model")

# %%
#Writing to the header file
with open('network_model.h', 'w') as file:
    file.write(header_str)

# %% [markdown]
# ## Generating Samples for Inference on Arduino

# %%
# Converting a sample piece of the X test and y test data to C (for the purpose of ino code (arduino) to load and test
# the sample and compare

Xtest = X_test[5:15,:]
print(c_writer.create_array(Xtest,"float","X_test"))
# Out:
# const unsigned int X_test_dim1 = 10;
# const unsigned int X_test_dim2 = 38;
#
# const float X_test[10][38] = {
#     -0.11024922321249885, 2.219311849644404, -1.1761894520278895,
#     0.7511112872365361, -0.007754404695011096, -0.004899993481519603,
#     -0.08948642202040107, -0.09507567152556495, -0.8092618187059747,
#     -0.011663642603760032, -0.036651869142258646, -0.024436507262009306,
#     -0.01238515036740332, -0.02618002418454278, -0.018609896340735923,
#     -0.04122119759327531, -0.0028174939213690777, -0.0975309439715147,
#     0.1824537789258241, 1.063695535988908, -0.6372092679572258,
#     -0.6319290328885425, -0.37436223991967527, -0.37443160310530493,
#     0.7712831058493207, -0.349683030873482, -0.37455970440553465,
#     0.7343425609306344, 1.2497210379081434, 1.0664013456654926,
#     -0.3861460041139426, -0.4801968475158174, -0.28910340026287856,
#     -0.6395319051152512, -0.6248707997445304, -0.38763462350750655,
#     -0.3763870260680415, 0.21642633142264128, -0.11024922321249885,
#     -0.12470615670462065, -0.44208308523109213, 0.7511112872365361,
#     -0.007722208768698085, -0.004826633266178868, -0.08948642202040107,
#     -0.09507567152556495, 1.2356940323701657, -0.011663642603760032,
#     -0.036651869142258646, -0.024436507262009306, -0.01238515036740332,
#     -0.02618002418454278, -0.018609896340735923, -0.04122119759327531,
#     -0.0028174939213690777, -0.0975309439715147, -0.6995794866568942,
#     -0.32680812408381416, -0.07724097848470314, -0.07267084522020971,
#     -0.37436223991967527, -0.37443160310530493, 0.7712831058493207,
#     -0.349683030873482, -0.37455970440553465, 0.7343425609306344,
#     1.2587542737799418, 1.0664013456654926, -0.43907816809041417,
#     -0.4801968475158174, -0.28910340026287856, -0.6395319051152512,
#     -0.6248707997445304, -0.38763462350750655, -0.3763870260680415,
#     -0.6563667617603728, -0.11024922321249885, -0.12470615670462065,
#     -0.44208308523109213, 0.7511112872365361, -0.007727489582008685,
#     -0.0048552313162269515, -0.08948642202040107, -0.09507567152556495,
#     1.2356940323701657, -0.011663642603760032, -0.036651869142258646,
#     -0.024436507262009306, -0.01238515036740332, -0.02618002418454278,
#     -0.018609896340735923, -0.04122119759327531, -0.0028174939213690777,
#     -0.0975309439715147, -0.6297154656206392, -0.20290185734466074,
#     -0.6372092679572258, -0.6319290328885425, -0.37436223991967527,
#     -0.37443160310530493, 0.7712831058493207, -0.349683030873482,
#     0.20274202288928514, -1.5034293926164772, 1.2587542737799418,
#     1.0664013456654926, -0.43907816809041417, -0.38310818187794965,
#     0.06625202510982187, -0.6395319051152512, -0.6248707997445304,
#     -0.38763462350750655, -0.3763870260680415, 0.6528228780141483,
#     -0.11024922321249885, -0.12470615670462065, -0.44208308523109213,
#     0.7511112872365361, -0.007734644232300465, -0.003699372736892263,
#     -0.08948642202040107, -0.09507567152556495, 1.2356940323701657,
#     -0.011663642603760032, -0.036651869142258646, -0.024436507262009306,
#     -0.01238515036740332, -0.02618002418454278, -0.018609896340735923,
#     -0.04122119759327531, -0.0028174939213690777, -0.0975309439715147,
#     -0.6035164577320437, -0.17536713140262664, -0.6372092679572258,
#     -0.6319290328885425, -0.37436223991967527, -0.37443160310530493,
#     0.7712831058493207, -0.349683030873482, -0.37455970440553465,
#     -1.0800671311345913, 1.2587542737799418, 1.0664013456654926,
#     -0.43907816809041417, -0.4478339589698615, 0.06625202510982187,
#     -0.6395319051152512, -0.6248707997445304, -0.38763462350750655,
#     -0.3763870260680415, 0.6528228780141483, -0.11024922321249885,
#     2.219311849644404, 0.7814275260969035, 0.7511112872365361,
#     -0.007762070391752289, -0.004918644383724874, -0.08948642202040107,
#     -0.09507567152556495, -0.8092618187059747, -0.011663642603760032,
#     -0.036651869142258646, -0.024436507262009306, -0.01238515036740332,
#     -0.02618002418454278, -0.018609896340735923, -0.04122119759327531,
#     -0.0028174939213690777, -0.0975309439715147, -0.6297154656206392,
#     -0.3681102129968653, -0.6372092679572258, -0.6319290328885425,
#     -0.37436223991967527, -0.37443160310530493, -1.3214280114927377,
#     4.253406127916395, -0.37455970440553465, 0.7343425609306344,
#     -1.0356876376568842, -1.161030186584037, 0.3549042915566595,
#     0.7819558057764636, -0.28910340026287856, -0.6395319051152512,
#     -0.6248707997445304, 1.3738692290095953, -0.3763870260680415,
#     -1.529159854943387, -0.11024922321249885, -0.12470615670462065,
#     0.10849668986650589, -2.2235805674567635, -0.00776224074056876,
#     -0.004918644383724874, -0.08948642202040107, -0.09507567152556495,
#     -0.8092618187059747, -0.011663642603760032, -0.036651869142258646,
#     -0.024436507262009306, -0.01238515036740332, -0.02618002418454278,
#     -0.018609896340735923, -0.04122119759327531, -0.0028174939213690777,
#     -0.0975309439715147, -0.7257784945454897, -0.3681102129968653,
#     -0.6372092679572258, -0.6319290328885425, 2.7464027950834815,
#     2.715364578035608, 0.7712831058493207, -0.349683030873482,
#     -0.37455970440553465, -1.1506275080482389, -1.0356876376568842,
#     -1.1387558712615415, 4.854138229556743, -0.4478339589698615,
#     -0.28910340026287856, -0.6395319051152512, -0.6248707997445304,
#     2.6786868975407816, 2.753913722653446, -1.965556401534894,
#     -0.11024922321249885, -0.12470615670462065, 1.0873051789289023,
#     -0.7362346401101137, -0.00776224074056876, -0.004918644383724874,
#     -0.08948642202040107, -0.09507567152556495, -0.8092618187059747,
#     -0.011663642603760032, -0.036651869142258646, -0.024436507262009306,
#     -0.01238515036740332, -0.02618002418454278, -0.018609896340735923,
#     -0.04122119759327531, -0.0028174939213690777, -0.0975309439715147,
#     0.35711383151646137, -0.35434285002584825, 1.602663889932865,
#     1.6051037177847889, -0.37436223991967527, -0.37443160310530493,
#     -1.4579091713193935, 0.03852930781964016, -0.37455970440553465,
#     0.7343425609306344, -0.8911558637081078, -1.0051099793265696,
#     -0.06855302025511306, -0.4801968475158174, -0.28910340026287856,
#     1.6087590765792643, 1.6189552037455606, -0.38763462350750655,
#     -0.3763870260680415, 0.6528228780141483, -0.11024922321249885,
#     -0.12470615670462065, -0.44208308523109213, -0.7362346401101137,
#     -0.00776224074056876, -0.004918644383724874, -0.08948642202040107,
#     -0.09507567152556495, -0.8092618187059747, -0.011663642603760032,
#     -0.036651869142258646, -0.024436507262009306, -0.01238515036740332,
#     -0.02618002418454278, -0.018609896340735923, -0.04122119759327531,
#     -0.0028174939213690777, -0.0975309439715147, -0.7257784945454897,
#     -0.35434285002584825, 1.602663889932865, 0.48658734244812313,
#     -0.37436223991967527, 1.1704664874651518, 0.7712831058493207,
#     -0.349683030873482, 3.4741184775599305, -1.775590846426261,
#     0.08443361044613316, 1.0664013456654926, -0.43907816809041417,
#     0.0699722577654333, 1.1323183012279232, 1.6087590765792643,
#     -0.5126794995700259, -0.38763462350750655, 2.5973986852173714,
#     -1.09276330835188, -0.11024922321249885, 2.219311849644404,
#     -1.1761894520278895, 0.7511112872365361, -0.007754915741460509,
#     -0.004907951199793851, -0.08948642202040107, -0.09507567152556495,
#     -0.8092618187059747, -0.011663642603760032, -0.036651869142258646,
#     -0.024436507262009306, -0.01238515036740332, -0.02618002418454278,
#     -0.018609896340735923, -0.04122119759327531, -0.0028174939213690777,
#     -0.0975309439715147, 1.0557540418790106, 2.4404318330906127,
#     -0.6372092679572258, -0.6319290328885425, -0.37436223991967527,
#     -0.37443160310530493, 0.7712831058493207, -0.349683030873482,
#     -0.37455970440553465, 0.7343425609306344, 1.2587542737799418,
#     1.0664013456654926, -0.43907816809041417, -0.4478339589698615,
#     -0.28910340026287856, -0.6395319051152512, -0.6248707997445304,
#     -0.38763462350750655, -0.3763870260680415, -0.6563667617603728,
#     -0.10410602127184165, -0.12470615670462065, 1.3931828317609012,
#     0.7511112872365361, -0.0074770768217963775, -0.004837575128805961,
#     -0.08948642202040107, -0.09507567152556495, 1.2356940323701657,
#     -0.011663642603760032, -0.036651869142258646, -0.024436507262009306,
#     -0.01238515036740332, -0.02618002418454278, -0.018609896340735923,
#     -0.04122119759327531, -0.0028174939213690777, -0.0975309439715147,
#     -0.7257784945454897, -0.35434285002584825, -0.6372092679572258,
#     -0.6319290328885425, -0.37436223991967527, -0.37443160310530493,
#     0.7712831058493207, -0.349683030873482, 3.4741184775599305,
#     -0.51558411582541, -0.06913139937444181, 0.6654636698605771,
#     -0.33321384013747096, -0.4478339589698615, -0.28910340026287856,
#     -0.6395319051152512, -0.6248707997445304, -0.38763462350750655,
#     -0.3763870260680415, 0.6528228780141483
# };

# %%
ytest=y_test[5:15]
print(c_writer.create_array(ytest,"uint8_t","y_test"))
# Out:
# const unsigned int y_test_dim1 = 10;
# const unsigned int y_test_dim2 = 1;
#
# const uint8_t y_test[10][1] = {
#     1, 1, 1, 1, 0, 0, 0, 1, 1, 1
# };
